# %% [markdown]
# Рибачок Ірина, ФІТ 4-8

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

from tensorflow.keras.layers import (Input, Rescaling, RandomFlip, RandomRotation, RandomContrast,
                                     Conv2D, BatchNormalization, MaxPool2D,
                                     GlobalAveragePooling2D, Dense, Dropout)

from tensorflow.keras.regularizers import l2

# %% [markdown]
# ВАРІАНТ 1

# %%
# Шлях до директорії з тренувальними зображеннями
train_images_dir = '/kaggle/input/gtsrb-german-traffic-sign/Train'

# Списки для зображень і міток
images = []
labels = []

# Проходимо по кожній папці (класу)
for class_folder in os.listdir(train_images_dir):
    class_folder_path = os.path.join(train_images_dir, class_folder)
    
    # Перевіряємо, чи є це папка, і якщо так, то зберігаємо зображення
    if os.path.isdir(class_folder_path):
        for image_file in os.listdir(class_folder_path):
            # Створення шляху до зображення
            img_path = os.path.join(class_folder_path, image_file)
            # Завантаження зображення
            img = image.load_img(img_path, target_size=(32, 32))  # зміна розміру на 32x32
            img_array = image.img_to_array(img)
            
            # Додаємо зображення в список
            images.append(img_array)
            # Додаємо мітку класу (число)
            labels.append(int(class_folder))

# Перетворюємо списки у NumPy масиви
images = np.array(images)
labels = np.array(labels)

# Перевірка форми даних
print(f"Форма зображень: {images.shape}")
print(f"Мітки класів: {labels.shape}")
# Out:
# Форма зображень: (39209, 32, 32, 3)
# Мітки класів: (39209,)

# %%
# Поділ на тренувальні та тестові дані
X_train, X_test, y_train, y_test = train_test_split(
    images, labels, test_size=0.2, random_state=42, stratify=labels
)

print(f"Розмір тренувальних даних: {X_train.shape}")
print(f"Розмір тестових даних: {X_test.shape}")
# Out:
# Розмір тренувальних даних: (31367, 32, 32, 3)
# Розмір тестових даних: (7842, 32, 32, 3)

# %%
# Перетворення міток на one-hot encoding
y_train = to_categorical(y_train, num_classes=43)
y_test = to_categorical(y_test, num_classes=43)

print(f"Форма y_train після перетворення: {y_train.shape}")  # Очікується (кількість_зразків, 43)
print(f"Форма y_test після перетворення: {y_test.shape}")    # Очікується (кількість_зразків, 43)
# Out:
# Форма y_train після перетворення: (31367, 43)
# Форма y_test після перетворення: (7842, 43)

# %%
height, width, channels = 32, 32, 3  
NUM_CATEGORIES = 43  # Кількість класів для GTSRB

# Створення моделі
model = Sequential([
    Input(shape=(height, width, channels)),

    # Нормалізація + аугментації 
    Rescaling(1./255),
    RandomFlip("horizontal"),           
    RandomRotation(0.05),
    RandomContrast(0.1),

    # Блок 1
    Conv2D(32, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPool2D(),

    # Блок 2
    Conv2D(64, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPool2D(),

    # Блок 3
    Conv2D(128, (3,3), padding="same", activation="relu", kernel_regularizer=l2(1e-4)),
    BatchNormalization(),
    MaxPool2D(),

    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(NUM_CATEGORIES, activation="softmax")
])

# %%
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import TopKCategoricalAccuracy

LOSS = CategoricalCrossentropy()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=LOSS,
    metrics=[
        "accuracy",                  
        TopKCategoricalAccuracy(k=3, name="top3")
    ]
)

cb = [
    tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=8, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),  # щоб працював val_accuracy і val_loss
    epochs=50,
    batch_size=32,
    shuffle=True,
    callbacks=cb,
    verbose=1
)
# Out:
# Epoch 1/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 27s 20ms/step - accuracy: 0.1229 - loss: 3.4949 - top3: 0.2632 - val_accuracy: 0.4313 - val_loss: 2.0327 - val_top3: 0.6721 - learning_rate: 3.0000e-04
# Epoch 2/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.4034 - loss: 1.9802 - top3: 0.6600 - val_accuracy: 0.6738 - val_loss: 1.1217 - val_top3: 0.8829 - learning_rate: 3.0000e-04
# Epoch 3/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.6334 - loss: 1.1895 - top3: 0.8444 - val_accuracy: 0.8583 - val_loss: 0.5370 - val_top3: 0.9796 - learning_rate: 3.0000e-04
# Epoch 4/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.7685 - loss: 0.7324 - top3: 0.9389 - val_accuracy: 0.9128 - val_loss: 0.3192 - val_top3: 0.9908 - learning_rate: 3.0000e-04
# Epoch 5/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.8414 - loss: 0.5029 - top3: 0.9712 - val_accuracy: 0.9406 - val_loss: 0.2110 - val_top3: 0.9941 - learning_rate: 3.0000e-04
# Epoch 6/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.8837 - loss: 0.3729 - top3: 0.9831 - val_accuracy: 0.9605 - val_loss: 0.1505 - val_top3: 0.9973 - learning_rate: 3.0000e-04
# Epoch 7/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9023 - loss: 0.3179 - top3: 0.9855 - val_accuracy: 0.9549 - val_loss: 0.1440 - val_top3: 0.9966 - learning_rate: 3.0000e-04
# Epoch 8/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9227 - loss: 0.2471 - top3: 0.9923 - val_accuracy: 0.9649 - val_loss: 0.1203 - val_top3: 0.9977 - learning_rate: 3.0000e-04
# Epoch 9/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9262 - loss: 0.2343 - top3: 0.9910 - val_accuracy: 0.9709 - val_loss: 0.1001 - val_top3: 0.9983 - learning_rate: 3.0000e-04
# Epoch 10/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9432 - loss: 0.1869 - top3: 0.9946 - val_accuracy: 0.9719 - val_loss: 0.0997 - val_top3: 0.9980 - learning_rate: 3.0000e-04
# Epoch 11/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9450 - loss: 0.1810 - top3: 0.9942 - val_accuracy: 0.9739 - val_loss: 0.0899 - val_top3: 0.9982 - learning_rate: 3.0000e-04
# Epoch 12/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.9513 - loss: 0.1657 - top3: 0.9953 - val_accuracy: 0.9810 - val_loss: 0.0729 - val_top3: 0.9989 - learning_rate: 3.0000e-04
# Epoch 13/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.9540 - loss: 0.1578 - top3: 0.9951 - val_accuracy: 0.9865 - val_loss: 0.0564 - val_top3: 0.9992 - learning_rate: 3.0000e-04
# Epoch 14/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9595 - loss: 0.1370 - top3: 0.9963 - val_accuracy: 0.9874 - val_loss: 0.0554 - val_top3: 0.9991 - learning_rate: 3.0000e-04
# Epoch 15/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9633 - loss: 0.1249 - top3: 0.9979 - val_accuracy: 0.9820 - val_loss: 0.0640 - val_top3: 0.9991 - learning_rate: 3.0000e-04
# Epoch 16/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9602 - loss: 0.1289 - top3: 0.9975 - val_accuracy: 0.9833 - val_loss: 0.0608 - val_top3: 0.9992 - learning_rate: 3.0000e-04
# Epoch 17/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9665 - loss: 0.1180 - top3: 0.9970 - val_accuracy: 0.9887 - val_loss: 0.0499 - val_top3: 0.9996 - learning_rate: 3.0000e-04
# Epoch 18/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9686 - loss: 0.1102 - top3: 0.9975 - val_accuracy: 0.9855 - val_loss: 0.0631 - val_top3: 0.9986 - learning_rate: 3.0000e-04
# Epoch 19/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9706 - loss: 0.1025 - top3: 0.9978 - val_accuracy: 0.9903 - val_loss: 0.0438 - val_top3: 0.9994 - learning_rate: 3.0000e-04
# Epoch 20/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9701 - loss: 0.1046 - top3: 0.9977 - val_accuracy: 0.9850 - val_loss: 0.0615 - val_top3: 0.9982 - learning_rate: 3.0000e-04
# Epoch 21/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9716 - loss: 0.1028 - top3: 0.9975 - val_accuracy: 0.9879 - val_loss: 0.0530 - val_top3: 0.9994 - learning_rate: 3.0000e-04
# Epoch 22/50
# 978/981 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9736 - loss: 0.0982 - top3: 0.9982
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9736 - loss: 0.0982 - top3: 0.9982 - val_accuracy: 0.9893 - val_loss: 0.0479 - val_top3: 0.9996 - learning_rate: 3.0000e-04
# Epoch 23/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9790 - loss: 0.0804 - top3: 0.9987 - val_accuracy: 0.9912 - val_loss: 0.0401 - val_top3: 0.9994 - learning_rate: 1.5000e-04
# Epoch 24/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.9826 - loss: 0.0694 - top3: 0.9991 - val_accuracy: 0.9923 - val_loss: 0.0376 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 25/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.9847 - loss: 0.0635 - top3: 0.9993 - val_accuracy: 0.9922 - val_loss: 0.0368 - val_top3: 0.9997 - learning_rate: 1.5000e-04
# Epoch 26/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.9838 - loss: 0.0675 - top3: 0.9990 - val_accuracy: 0.9938 - val_loss: 0.0354 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 27/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.9829 - loss: 0.0647 - top3: 0.9992 - val_accuracy: 0.9943 - val_loss: 0.0357 - val_top3: 0.9997 - learning_rate: 1.5000e-04
# Epoch 28/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9841 - loss: 0.0638 - top3: 0.9992 - val_accuracy: 0.9943 - val_loss: 0.0351 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 29/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9842 - loss: 0.0643 - top3: 0.9987 - val_accuracy: 0.9943 - val_loss: 0.0349 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 30/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9866 - loss: 0.0583 - top3: 0.9993 - val_accuracy: 0.9927 - val_loss: 0.0371 - val_top3: 0.9997 - learning_rate: 1.5000e-04
# Epoch 31/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9860 - loss: 0.0563 - top3: 0.9993 - val_accuracy: 0.9936 - val_loss: 0.0344 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 32/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.9864 - loss: 0.0573 - top3: 0.9992 - val_accuracy: 0.9935 - val_loss: 0.0347 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 33/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9872 - loss: 0.0544 - top3: 0.9995 - val_accuracy: 0.9935 - val_loss: 0.0348 - val_top3: 0.9995 - learning_rate: 1.5000e-04
# Epoch 34/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9867 - loss: 0.0563 - top3: 0.9992 - val_accuracy: 0.9941 - val_loss: 0.0326 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 35/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9866 - loss: 0.0550 - top3: 0.9993 - val_accuracy: 0.9940 - val_loss: 0.0325 - val_top3: 0.9995 - learning_rate: 1.5000e-04

# %%
training_accuracy = history.history["accuracy"]
training_loss = history.history["loss"]
validation_accuracy = history.history["val_accuracy"]
validation_loss = history.history["val_loss"]

# %%
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.plot(training_accuracy, color = "red", label = "Training Accuracy")
plt.plot(validation_accuracy, color = "cyan", label = "Validation Accuracy")
plt.legend()
plt.grid(True)
plt.title("Accuracy")
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(training_loss, color = "red", label = "Training Loss")
plt.plot(validation_loss, color = "cyan", label = "Validation Loss")
plt.grid(True)
plt.legend()
plt.title("Loss")
plt.xlabel("Number of epochs")
plt.ylabel("Loss")

plt.tight_layout()
plt.show()

# %%
random_indices = np.random.choice(len(X_test), size=10, replace=False)

# Прогнозування класів для тестових даних
y_pred = model.predict(X_test)

# Виведення зображень та їхніх прогнозованих і справжніх класів
plt.figure(figsize=(15, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])  # Показуємо зображення
    plt.axis('off')
    
    true_class = np.argmax(y_test[idx])  # Справжній клас
    predicted_class = np.argmax(y_pred[idx])  # Прогнозований клас
    
    plt.title(f"True: {true_class}, Pred: {predicted_class}")

plt.tight_layout()
plt.show()
# Out:
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
